# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://user-images.githubusercontent.com/37101144/161836199-fdb0219d-0361-4988-bf26-48b0fad160a3.png"
#      width="200px"
#      height="auto"/>
# </p>

# %% [markdown]
# ##--- Prereqs
# UC:   CRUD in Google Drive from Colab
# - grant Colab access to Google Drive
#
# UC:   Open notebook file directly from Google Drive into Colab
# - add chrome browser plugin for Colab
#
# UC:   ready colab project session folder with prework files
# - manually copy/upload project files
#
# UC:   Update req libraries
# - run pip install -r ./prereqs/requirements.txt

# %%
#--- mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#--- unmount google drive
from google.colab import drive
drive.flush_and_unmount()

# %%
# %%sh
# #pip install 'ipython~=7.9.0' --force-reinstall       #--- ERROR:  ensure that colab req of ipython 7.9.0 is adhered to
# #pip install -r ./prereqs/requirements.txt            #--- ERROR:  ipython 8.4.0 installed;  only 7.9.0 reqd by colab
#
# #pip install 'matplotlib==3.5.2'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ...

# %%
# %%sh
# #pwd
# ls -la
# #mkdir prereqs
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Dec  8 21:49 .
# drwxr-xr-x 1 root root 4096 Dec  8 21:37 ..
# drwxr-xr-x 4 root root 4096 Dec  7 14:40 .config
# drwx------ 5 root root 4096 Dec  8 21:49 drive
# drwxr-xr-x 2 root root 4096 Dec  8 21:53 prereqs
# drwxr-xr-x 1 root root 4096 Dec  7 14:41 sample_data

# %%
# !pip install streamlit             #--- manually install streamlit library
# !pip install shap                  #--- manually install shap library
# !pip install tpot                  #--- manually install tpot library

#!pip show ipython matplotlib numpy pandas plotly scikit_learn seaborn shap streamlit tensorflow tpot
#pip freeze
#pip list 

#!pip install matplotlib numpy pandas plotly scikit_learn seaborn shap streamlit tensorflow tpot -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.2 MB 26.5 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 61.1 MB/s
# ...
#      |████████████████████████████████| 78 kB 8.5 MB/s
# ...
#      |████████████████████████████████| 164 kB 81.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 71.3 MB/s
# ...
#      |████████████████████████████████| 237 kB 68.7 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 51 kB 7.9 MB/s
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=eb91bbb2fd0656d80cd34f3100da952bb8778a822bd124afd317d8d0bad7ad85
#   Stored in directory: /root/.cache/pip/wheels/19/09/72/3eb74d236bb48bd0f3c6c3c83e4e0c5bbfcbcad7c6c3539db8
# Successfully built validators
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import shap

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.9.2

# %%
from tpot import TPOTRegressor, TPOTClassifier
