# %% [markdown]
# # 1. Install dependencies

# %%
# %%bash
# #--- cd to project root folder
# %cd ~/myLurn*/fourth*/code/fourth*    #--- not working ?!
# cd ..
# pwd
#
# #git status
# git rev-parse --abbrev-ref HEAD       #--- display only the current/active branch
# Out:
# bash: /home/kidcoconut/miniconda3/envs/week2/lib/libtinfo.so.6: no version information available (required by bash)
# bash: line 2: fg: no job control
# /home/kidcoconut/myLurnins/fourthbrain.ai/code/fourthbrain-mle10
# week2_assignment

# %%
#--- this was taking a very long time [*];  ran in the bash shell

# !pip install -q transformers
# Out:
# /bin/bash: /home/kidcoconut/miniconda3/envs/week2/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %% [markdown]
# # 2. Run sentiment analysis predictions by using Pipeline

# %%
# %%bash
# #--- prereqs:  you need to install tensorflow or pytorch
#
# #--- Requires the latest pip
# !pip install --upgrade pip
#
# #--- Current stable release for CPU and GPU
# #--- pip install did not work;  tried conda install tensorflow
# !pip install tensorflow
# Out:
# bash: /home/kidcoconut/miniconda3/envs/week2/lib/libtinfo.so.6: no version information available (required by bash)
# bash: line 4: !pip: command not found
# bash: line 8: !pip: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '#--- prereqs:  you need to install tensorflow or pytorch\n\n#--- Requires the latest pip\n!pip install --upgrade pip\n\n#--- Current stable release for CPU and GPU\n#--- pip install did not work;  tried conda install tensorflow\n!pip install tensorflow\n\n')
#
# File ~/miniconda3/envs/py39_12/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
# ...

# %%
#--- clean code
#--- use pipeline lib to make predictions from available Hub models
from transformers import pipeline as libPipe

#--- initialize pipeline
#    pipe_task = pipeline (‘task_name’,model=’model_name’, tokenizer, frmamework='pt|tf');  PyTorch, Tensorflow
tskSentiment = libPipe("sentimentAnalysis", framework='tf')

#--- populate pipeline with sentiment data
aryData - ["I love you", "I hate you"]
tskSentiment(aryData)

# %%
# Using pipeline class to make predictions from models available in the Hub in an easy way 
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis", framework='pt')
data = ["I love you", "I hate you"]
sentiment_pipeline(data)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
# ...

# %% [markdown]
# # 3. Use a specific sentiment analysis model available on the Hub by specifying its name

# %%
# Using a specific model for sentiment analysis
specific_model = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
specific_model(data)
# Out:
# Downloading:   0%|          | 0.00/987 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/890 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/515M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/824k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Please install emoji: pip3 install emoji
# [{'label': 'POS', 'score': 0.9903131723403931},
#  {'label': 'NEG', 'score': 0.9797351360321045}]
